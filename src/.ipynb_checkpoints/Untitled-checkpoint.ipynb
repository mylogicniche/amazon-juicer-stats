# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas as pd
import re
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from collections import Counter
#from nltk.corpus import stopwords
import string
import operator
import seaborn as sns
# %matplotlib inline

# %%
with open("../out/juicers.json", "r") as f:
    allJuicers = json.load(f)

priceListByBrand = {}
rankListByBrand = {}
juicersByAsin = {}
for cat, juicers in allJuicers.items():
    for juicer in juicers:
        asin = list(juicer.keys())[0]
        val = list(juicer.values())[0]
        val.update({"category":cat})
        if any(x in val['title'].lower() for x in ['juice','juicer']):
            juicersByAsin.update({asin: val})
        else:
            continue
        brand = val['brand']
        try:
            if brand.lower() == 'breville juicer':
                brand = 'breville'
        except:
            continue

        try:
            if brand.lower() == 'omega juicers':
                brand = 'omega'
        except:
            continue
        try:
            priceListByBrand.setdefault(brand, []).append(float(val['price'][1:]))
        except:
            pass

        try:
            if not val['sales_rank'] == 'None':
                rankListByBrand.setdefault(brand, []).append(int(val['sales_rank']))
        except:
            pass

df_all = pd.DataFrame(juicersByAsin)

df_all.head()
# Out:
#                                                  B00004R93U  \
# brand                                              Juiceman
# category                                        centrifugal
# color                                             Off-White
# features  [Peppy 1/4-horsepower motor quickly juices mos...
# price                                               $158.98
#
#                                                  B00004R93V  \
# brand                                              Juiceman
# category                                        centrifugal
# color                                                 White
# features  [Powerful 1/2-horsepower motor quickly juices ...
# price                                                $79.95
#
#                                                  B00004S8FH  \
# brand                                                Waring
# category                                        centrifugal
# color                                                 White
# features  [Converts all noncitrus fruits and vegetables ...
# price                                               $360.00
#
#                                                  B00004S8FI  \
# brand                                                Waring
# category                                             citrus
# color                                           Quite White
# features  [Juices all citrus fruits, from limes to grape...
# price                                                  None
#
#                                                  B00004S8FJ  \
# brand                                                Waring
# category                                             citrus
# color                                       Stainless Steel
# features  [Juices all citrus fruits, from limes to grape...
# price                                               $149.99
#
#                                                  B00004SC51  \
# brand                                          BLACK+DECKER
# category                                             citrus
# color                                                  None
# features  [Large 1 liter (34 ounce) pitcher, Adjustable ...
# price                                                $59.32
#
#                                                  B00004X139  \
# brand                                        Hamilton Beach
# category                                        centrifugal
# color                                                 White
# features  [This Hamilton Beach HealthSmart Juice Extract...
# price                                                $42.38
#
#                                                  B00005MF9O  \
# brand                                          BLACK+DECKER
# category                                             citrus
# color                                                  Blue
# features  [Electric juicer, beverage stirrer, and servin...
# price                                                $48.99
#
#                                                  B00005OTY9  \
# brand                                              Juiceman
# category                                        centrifugal
# color                                                 White
# features  [Automatic fruit and vegetable juicer for freq...
# price                                                  None
#
#                                                  B00005V3W4  \
# brand                                        Hamilton Beach
# category                                        centrifugal
# color                                                  None
# features  [Extracts juice from raw fruits and vegetables...
# price                                                $41.89
#
#                                 ...                           B072KSZ8KD  \
# brand                           ...                          Robot Coupe
# category                        ...                          centrifugal
# color                           ...                                 None
# features                        ...                                   []
# price                           ...                            $1,598.10
#
#                                                  B072NBBHWJ   B072ND9V5C  \
# brand                                                XmiPbs  Robot Coupe
# category                                             citrus  centrifugal
# color                                                  Pink         None
# features  [Mini juicer cup in size, portable and great f...           []
# price                                                $29.99    $1,993.95
#
#                                                  B072P2YQXD  \
# brand                                                Pawaca
# category                                        masticating
# color                                                 Green
# features  [Juicer Cup, Battery Powered Electric Juice Bl...
# price                                                $22.29
#
#                                                  B072SV42RJ  \
# brand                                        Frigidairenire
# category                                        centrifugal
# color                                                Purple
# features  [SUPPLY THE NUTRITION: Supply the nutrition th...
# price                                                $15.99
#
#                                                  B072TZ3F78  \
# brand                                               iPstyle
# category                                        centrifugal
# color                                                 Green
# features  [Portable Personal Blender Multifunctional : s...
# price                                                $27.99
#
#                                                  B072VL3FXH  \
# brand                                               Decdeal
# category                                        centrifugal
# color                                                  None
# features  [One machine with multiple function (one in al...
# price                                               $119.99
#
#                                                  B072WPDGDN  \
# brand                                               Raylans
# category                                        centrifugal
# color                                                  Blue
# features  [Food grade materials, safe and non-toxic, Lig...
# price                                                $18.53
#
#                                                  B073345HMW  \
# brand                                                   GTT
# category                                        centrifugal
# color                                                Purple
# features  [♨MATERIAL ♨ Made of eco-friendly & food-grade...
# price                                                $19.99
#
#                                                  B0739LW3XS
# brand                                              LOVSHARE
# category                                        centrifugal
# color                                                  None
# features  [Dimension: 432 x 444 x 350mm / 17 x 17.5 x 13...
# price                                               $633.99
#
# [5 rows x 1017 columns]

# %%
df_all = df_all.T
df_all.head()
# Out:
#                brand     category            color  \
# B00004R93U  Juiceman  centrifugal        Off-White
# B00004R93V  Juiceman  centrifugal            White
# B00004S8FH    Waring  centrifugal            White
# B00004S8FI    Waring       citrus      Quite White
# B00004S8FJ    Waring       citrus  Stainless Steel
#
#                                                      features    price  \
# B00004R93U  [Peppy 1/4-horsepower motor quickly juices mos...  $158.98
# B00004R93V  [Powerful 1/2-horsepower motor quickly juices ...   $79.95
# B00004S8FH  [Converts all noncitrus fruits and vegetables ...  $360.00
# B00004S8FI  [Juices all citrus fruits, from limes to grape...     None
# B00004S8FJ  [Juices all citrus fruits, from limes to grape...  $149.99
#
#            sales_rank                                              title
# B00004R93U    1006304       Juiceman Jr. Elite Pro JM211 Juice Extractor
# B00004R93V     778846  The Juiceman Electronic Professional Series 41...
# B00004S8FH     227195  Waring PJE401 Juice Extractor, Quite White and...
# B00004S8FI     254788           Waring PCJ201 Citrus Juicer, Quite White
# B00004S8FJ     231125       Waring PCJ218 Citrus Juicer, Stainless Steel

# %%
df_all.isnull().sum()
# Out:
# brand           7
# category        0
# color         178
# features        0
# price          49
# sales_rank      0
# title           0
# dtype: int64

# %%
(df_all=='None').sum()
# Out:
# brand           0
# category        0
# color           1
# features        0
# price           0
# sales_rank    252
# title           0
# dtype: int64

# %%
df_all[df_all == 'None'] = float('NaN')

# %%
(df_all=='None').sum()
# Out:
# brand         0
# category      0
# color         0
# features      0
# price         0
# sales_rank    0
# title         0
# dtype: int64

# %%
df_all.isnull().sum()
# Out:
# brand           7
# category        0
# color         179
# features        0
# price          49
# sales_rank    252
# title           0
# dtype: int64

# %%
print(df_all.columns)
print(df_all.shape)
# Out:
# Index(['brand', 'category', 'color', 'features', 'price', 'sales_rank',
#        'title'],
#       dtype='object')
# (1017, 7)

# %%
df_all.dropna(inplace=True)
# Out:
# (636, 7)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 636 entries, B00004R93U to B072WPDGDN
# Data columns (total 7 columns):
# brand         636 non-null object
# category      636 non-null object
# color         636 non-null object
# features      636 non-null object
# price         636 non-null object
# sales_rank    636 non-null object
# title         636 non-null object
# dtypes: object(7)
# memory usage: 39.8+ KB

# %%
df_all.dtypes
# Out:
# brand         object
# category      object
# color         object
# features      object
# price         object
# sales_rank     int64
# title         object
# dtype: object

# %%
for col in df_all.columns.tolist():
    try:
        print(col, df_all[col].unique().shape[0])
    except:
        continue
# Out:
# brand 256
# category 3
# color 142
# price 462
# sales_rank 636
# title 631

# %% [markdown]
# #### Convert some columns to lowercase string

# %%
strlist = ['brand', 'category', 'color', 'price', 'title']
df_all[strlist] = df_all[strlist].applymap(lambda x: x.lower())
df_all[strlist].head()
# Out:
#                      brand     category            color    price  \
# B00004R93U        juiceman  centrifugal        off-white  $158.98
# B00004R93V        juiceman  centrifugal            white   $79.95
# B00004S8FH          waring  centrifugal            white  $360.00
# B00004S8FJ          waring       citrus  stainless steel  $149.99
# B00004X139  hamilton beach  centrifugal            white   $42.38
#
#                                                         title
# B00004R93U       juiceman jr. elite pro jm211 juice extractor
# B00004R93V  the juiceman electronic professional series 41...
# B00004S8FH  waring pje401 juice extractor, quite white and...
# B00004S8FJ       waring pcj218 citrus juicer, stainless steel
# B00004X139                        juice extractor,healthsmart

# %% [markdown]
# #### Remove \$ sign and cast to float

# %%
def getPrice(x):
    x = x.replace(',','.')
    res = re.findall('\d+.\d+', x)
    if res:
        return res[0]
    else:
        return float('NaN')

df_all['price'] = df_all['price'].apply(getPrice)

# %%
df_all['price'].isnull().sum()
# Out:
# 15

# %%
df_all.dropna(inplace=True)

# %%
df_all['price'] = df_all['price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-1b0719702287> in <module>()
# ----> 1 df_all['price'] = df_all['price'].astype(float)
#
# /usr/local/lib/python3.5/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, raise_on_error, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     634
#     635     if copy:
# --> 636         return arr.astype(dtype)
#     637     return arr.view(dtype)
#     638
#
# ValueError: could not convert string to float: '2,396'

# %% [markdown]
# #### Cast sales_rank to int

# %%
df_all['sales_rank'] = df_all['sales_rank'].astype(int)

# %%
df_all.shape
# Out:
# (621, 7)

# %%
df_all['features'].iloc[0]
# Out:
# ['Peppy 1/4-horsepower motor quickly juices most fruits and vegetables',
#  'Makes tasty, nutritious, and additive-free juice blends',
#  'Stainless steel blade, basket with micro-mesh strainer to screen out pulp',
#  'Medium-capacity pulp receptacle for continuous juicing',
#  'Two-speed control for soft or hard produce']

# %%
df_all['brand'] = df_all['brand'].replace("breville juicer", "breville")
df_all['brand'] = df_all['brand'].replace("omega juicers", "omega")
df_all.head()
# Out:
#                         brand     category                     color  \
# B00004R93U           juiceman  centrifugal                 Off-White
# B00004R93V           juiceman  centrifugal                     White
# B00004S8FH             waring  centrifugal                     White
# B00004S8FJ             waring       citrus           Stainless Steel
# B00004X139     hamilton beach  centrifugal                     White
# B00005MF9O       black+decker       citrus                      Blue
# B00006IUZK        toastmaster       citrus                     White
# B00009ENKU              omega  masticating                     White
# B00009KO85             waring  centrifugal           Stainless Steel
# B0000DDVN4            l'equip  centrifugal                      Gray
# B0000DDVUO             waring  centrifugal               Quite White
# B0000VLI5K          cuisinart       citrus   Brushed stainless steel
# B0000ZP3MA            tribest  masticating                     White
# B0000ZP3MK            tribest  masticating                     White
# B00015NMWC     hamilton beach  centrifugal                      Blue
# B00016AFOE              oster  centrifugal                     White
# B0001IT0IY           breville  centrifugal                    Chrome
# B0001LB9R6       black+decker  centrifugal                     White
# B00023XDJA      proctor silex       citrus                     White
# B0002CA3TY     hamilton beach  centrifugal                    Yellow
# B0002CA3U8     hamilton beach  centrifugal                     White
# B0002JNMEU              oster       citrus                     White
# B0002OKDT2              omega  masticating                    Chrome
# B0002VAFVG           breville  centrifugal         Brushed Stainless
# B0006DOVGU              braun       citrus                     White
# B0007MU2O0           juiceman  centrifugal                      Gray
# B0007W160E              braun       citrus                     White
# B000AV3WF4   aroma housewares       citrus                     White
# B000E46IX0         healthwise  masticating            Black / Silver
# B000E48LGC      samson brands  masticating                     IVORY
# ...                       ...          ...                       ...
# B06XTDH92X  huanyu instrument  centrifugal                    Silver
# B06XTQD8BX            fivebop  masticating                    Purple
# B06XVG9DTP              braun  centrifugal                     Black
# B06XWT9KZ1             newpal  masticating                       Red
# B06XWWR9VM       first4spares  centrifugal                     White
# B06XXY3YYR            ecvilla  masticating                       Red
# B06XXYJYWM       natalie styx       citrus       Black,Feeding Chute
# B06Y2DBF1T             onuemp  centrifugal                     Green
# B06Y2K3Y6D           breville  centrifugal                      Gray
# B06ZXXP7DP             topfit  masticating                     Green
# B0711BC8YH       buysevenside  masticating                       Red
# B07174K6XQ          winnereco       citrus                    Silver
# B0718WJ3NR             ovente  centrifugal                     Black
# B0719Q7751                zsl  masticating                    Purple
# B071D3WCTJ            orangea  centrifugal                  WF-A2000
# B071D549S7            runnept  centrifugal                 Dark Gray
# B071JL91JP          superland  centrifugal  22-30 Oranges per Minute
# B071JQXC8Y           e-uniona  centrifugal                     Green
# B071QYVR17            tribest  masticating                    Silver
# B071RWG1YG           lovshare  centrifugal                    Silver
# B071VK2TBD             pawaca  masticating                      Blue
# B071YHPCDP     hamilton beach  centrifugal                     White
# B071ZVQSP5              kuwan  centrifugal            watermelon red
# B0722L18HQ       buysevenside  masticating                       Red
# B0727PP8JX       prairie diva  centrifugal                     Green
# B072F6YFXJ             towabo  centrifugal                      Blue
# B072J2VHYJ            mophorn  centrifugal                    Manual
# B072JSQ159            genenic  centrifugal                     Green
# B072SV42RJ     frigidairenire  centrifugal                    Purple
# B072WPDGDN            raylans  centrifugal                      Blue
#
#                                                      features  \
# B00004R93U  [Peppy 1/4-horsepower motor quickly juices mos...
# B00004R93V  [Powerful 1/2-horsepower motor quickly juices ...
# B00004S8FH  [Converts all noncitrus fruits and vegetables ...
# B00004S8FJ  [Juices all citrus fruits, from limes to grape...
# B00004X139  [This Hamilton Beach HealthSmart Juice Extract...
# B00005MF9O  [Electric juicer, beverage stirrer, and servin...
# B00006IUZK  [34-ounce capacity, Dust cover, Cord storage, ...
# B00009ENKU  [250-watt continuous pulp-ejection-style juice...
# B00009KO85  [Juicer provides healthful way to eat fruits a...
# B0000DDVN4  [480-watt mini juicer for making healthy, fres...
# B0000DDVUO  [Professional juice extractor with 550-watt vi...
# B0000VLI5K  [Stainless steel design, Adjustable reamer wit...
# B0000ZP3MA  [Automatic pulp ejection for continuous juicin...
# B0000ZP3MK  [110V GS-1000 Model with deluxe set of juicing...
# B00015NMWC  [Exceptionally quiet motor to ensure customers...
# B00016AFOE  [Stainless steel cutter/strainer, 300 Watts of...
# B0001IT0IY  [Professional juice extractor adjusts to juici...
# B0001LB9R6  [Powerful 400-watt juice extractor produces pu...
# B00023XDJA  [Extra large 36 ounce capacity, Powerful auto ...
# B0002CA3TY  [350 watts, Easy to remove pulp bin, Stainless...
# B0002CA3U8  [This is a new Hamilton Beach 2 Speed Juice Ex...
# B0002JNMEU  [20-watt automatic juicer provides smooth, qui...
# B0002OKDT2  [Measures 14-1/2 by 6-1/2 by 15-1/2-inch; 10-y...
# B0002VAFVG  [1000-watt juicer with 2 speed controls, high ...
# B0006DOVGU  [220 Volt WILL NOT WORK IN THE UNITED STATES, ...
# B0007MU2O0  [Juice a wide variety of fruits and vegetable ...
# B0007W160E  [Will Not Work in USA & Canada, 220-240V 50hz,...
# B000AV3WF4  [Large, 1 quart serving pitcher, Simple, push ...
# B000E46IX0  [Juicing speed: 3 1/2 ounces per minute for mo...
# B000E48LGC  [Samson 6-1 produces high quality juice, Singl...
# ...                                                       ...
# B06XTDH92X  [It can resist decay, not easy to rust and eas...
# B06XTQD8BX  [New generation mini juicer, portable and grea...
# B06XVG9DTP  [International 220-240 Voltage Model! 220 Volt...
# B06XWT9KZ1  [Make fruit juice, vegetable juice, superfood ...
# B06XWWR9VM  [Juice Attachment For KitchenAid JE Citrus Jui...
# B06XXY3YYR  [Multifunctional: New generation mini juicer, ...
# B06XXYJYWM  [MATERIAL: TRITAN, Replacement Feeding Chute O...
# B06Y2DBF1T  [Multi-function Juicer-You can use it as water...
# B06Y2K3Y6D  [1 speed juicer, Quiet operation, Extra Wide-W...
# B06ZXXP7DP  [Environmental materials: Made of eco-friendly...
# B0711BC8YH  [8.6cm Diameter Large Feed Tube - Large tube i...
# B07174K6XQ  [Make delicious noodle and extract juice Easy ...
# B0718WJ3NR  [Easily fit whole fruits & vegetables for effo...
# B0719Q7751  [1. Multifuntional power: The powerful motor e...
# B071D3WCTJ  [Power: 550W, Net weight: 19Kg/41.88 Lbs, Rota...
# B071D549S7  [Powerful and easy for use. It just takes 60se...
# B071JL91JP  [Juicer extractor machine size: 20"(L)x20"(H)x...
# B071JQXC8Y  [[Commodity Material]: Material, Food Grade Pc...
# B071QYVR17  [All stainless steel twin gears - the green st...
# B071RWG1YG  [Dimension: 250 x 400 x 350mm / 9 x 15 x 13.5 ...
# B071VK2TBD  [Portable and multi-function, Small in size. S...
# B071YHPCDP  [This Certified Refurbished product is tested ...
# B071ZVQSP5  l capacity Built-in battery cycle charge,...
# B0722L18HQ  [400W Dual-Speed/Power Settings Motor - Low sp...
# B0727PP8JX  [Product Dimension: 78mm*78mm*220mm ON/OFF pow...
# B072F6YFXJ  [TOWABO New generation mini juicer, portable a...
# B072J2VHYJ  [Output: 50 kg/h; Juice Extraction Rate: (60-8...
# B072JSQ159  [New generation portable mini juicer is great ...
# B072SV42RJ  [SUPPLY THE NUTRITION: Supply the nutrition th...
# B072WPDGDN  [Food grade materials, safe and non-toxic, Lig...
#
#                          price sales_rank  \
# B00004R93U             $158.98    1006304
# B00004R93V              $79.95     778846
# B00004S8FH             $360.00     227195
# B00004S8FJ             $149.99     231125
# B00004X139              $42.38     919971
# B00005MF9O              $48.99    1232987
# B00006IUZK              $49.99     406459
# B00009ENKU             $129.95      64142
# B00009KO85              $57.38     392206
# B0000DDVN4             $108.80     239897
# B0000DDVUO             $300.00     802291
# B0000VLI5K              $29.95     123515
# B0000ZP3MA             $429.99     214086
# B0000ZP3MK             $479.00     347778
# B00015NMWC             $326.81     117845
# B00016AFOE              $35.45    1350746
# B0001IT0IY             $190.00     445723
# B0001LB9R6              $49.99     613587
# B00023XDJA              $14.93     148927
# B0002CA3TY              $29.99     300496
# B0002CA3U8              $75.00     885665
# B0002JNMEU              $99.99     186783
# B0002OKDT2             $228.99      87416
# B0002VAFVG  Too low to display       4626
# B0006DOVGU              $54.99     355438
# B0007MU2O0             $795.00    1486267
# B0007W160E              $58.66     523484
# B000AV3WF4              $33.46     124811
# B000E46IX0             $846.00     647984
# B000E48LGC             $229.00     283205
# ...                        ...        ...
# B06XTDH92X             $499.00    1358077
# B06XTQD8BX              $29.99     231291
# B06XVG9DTP             $109.99    1087053
# B06XWT9KZ1             $179.99    1434611
# B06XWWR9VM              $17.49      44845
# B06XXY3YYR              $33.99     582247
# B06XXYJYWM              $12.99     467127
# B06Y2DBF1T              $41.99     864310
# B06Y2K3Y6D             $149.99     158305
# B06ZXXP7DP              $32.99    1005401
# B0711BC8YH             $259.99      35418
# B07174K6XQ              $17.69     484022
# B0718WJ3NR              $39.99      16843
# B0719Q7751              $35.99     586538
# B071D3WCTJ             $599.99     278220
# B071D549S7              $24.99      70394
# B071JL91JP             $665.99     505962
# B071JQXC8Y              $26.99       3020
# B071QYVR17             $795.00     214769
# B071RWG1YG             $489.99     366652
# B071VK2TBD              $20.31     602418
# B071YHPCDP              $36.95      64116
# B071ZVQSP5              $25.99      43512
# B0722L18HQ              $75.99       8610
# B0727PP8JX              $29.99     339860
# B072F6YFXJ              $39.62        522
# B072J2VHYJ             $209.99     102212
# B072JSQ159              $21.99      98861
# B072SV42RJ              $15.99     204381
# B072WPDGDN              $18.53     282393
#
#                                                         title
# B00004R93U       Juiceman Jr. Elite Pro JM211 Juice Extractor
# B00004R93V  The Juiceman Electronic Professional Series 41...
# B00004S8FH  Waring PJE401 Juice Extractor, Quite White and...
# B00004S8FJ       Waring PCJ218 Citrus Juicer, Stainless Steel
# B00004X139                        Juice Extractor,Healthsmart
# B00005MF9O   Black & Decker BM300 Juice Wizard Beverage Maker
# B00006IUZK                     Toastmaster 1109 Citrus Juicer
# B00009ENKU  Omega 4000 Stainless-Steel 1/3-HP Continuous P...
# B00009KO85  Waring JEX328FR Health Juice Extractor (Certif...
# B0000DDVN4  L'Equip 306150 480 Watts Mini Pulp Ejection Ju...
# B0000DDVUO  Acme 5001 Juicerator 550-Watt Juice Extractor,...
# B0000VLI5K  Cuisinart Ccj-500 Pulp Control Citrus Juicer, ...
# B0000ZP3MA         Tribest Green Star GS-1000 Juice Extractor
# B0000ZP3MK  Tribest Green Star GS-3000 Deluxe Twin Gear Ju...
# B00015NMWC  Hamilton Beach 96700 Commercial Electric Juice...
# B00016AFOE               Oster 03165 Electric Juice Extractor
# B0001IT0IY      Breville JE95XL Two-Speed Juice Fountain Plus
# B0001LB9R6   Black & Decker JE1500 Fruit-and-Vegetable Juicer
# B00023XDJA           Proctor Silex 66332 Juicit Citrus Juicer
# B0002CA3TY              Hamilton Beach 67800H Juice Extractor
# B0002CA3U8                         Hb 2 Speed Juice Extractor
# B0002JNMEU  Oster 3186 Juice-n-Serve 27-Ounce Automatic Ci...
# B0002OKDT2  Omega J8005 Nutrition Center Single-Gear house...
# B0002VAFVG  Breville 800JEXL Juice Fountain Elite 1000-Wat...
# B0006DOVGU  Braun MPZ9 Multiquick 3 Citrus Juicer, 220 to ...
# B0007MU2O0                             Juiceman Pro - JM418SS
# B0007W160E  Overseas Use Only Braun Juicer Continuous Feed...
# B000AV3WF4     Aroma Housewares ACJ-181 1-Liter Citrus Juicer
# B000E46IX0  Wheateena Workhorse II Commercial Wheatgrass J...
# B000E48LGC  Samson 6-1 Single Auger Wheatgrass & Multi Pur...
# ...                                                       ...
# B06XTDH92X  WF-A4000 Commercial Stainless Steel Automatic ...
# B06XTQD8BX  Fivebop USB Fruit Juicer Cup Mixing Machine, P...
# B06XVG9DTP  Braun MP80 Juicer (NOT FOR USA) 220 Volt Euro ...
# B06XWT9KZ1  NewPal New Slow JuicerFruits Vegetables Low Sp...
# B06XWWR9VM  Juice Attachment For KitchenAid JE Citrus Juic...
# B06XXY3YYR  ECVILLA USB Juicer Cup, Fruit Mixing Machine, ...
# B06XXYJYWM  Natalie Styx Feed Chute for Wide Chute Slow Ma...
# B06Y2DBF1T  USB Juicer Cup, Fruit Mixing Machine, Portable...
# B06Y2K3Y6D         Breville JJE100 The Joe Cross Juicer, Grey
# B06ZXXP7DP  USB Juicer Cup, Portable Personal Size Eletric...
# B0711BC8YH  BuySevenSide best juicer Extractor for Low spe...
# B07174K6XQ  Noodle Maker,WinnerEco Pasta Press Machine Veg...
# B0718WJ3NR  LIMITED TIME OFFER Ovente Wide Mouth Juice Ext...
# B0719Q7751  Portable Mini Electric Fruit Juicer USB Juicin...
# B071D3WCTJ  OrangeA 550W Commercial Juice Extractor Heavy ...
# B071D549S7  RUNNEPT Beach Mini Portable Juice Blender and ...
# B071JL91JP  Superland Orange Juice Machine Commercial 120W...
# B071JQXC8Y  E-UNIONA Rechargeable Household Portable Mini ...
# B071QYVR17  Tribest GS-P502 Green star Pro Jumbo Twin Gear...
# B071RWG1YG  LOVSHARE Juice Extractor WF-A3000 Electric Jui...
# B071VK2TBD  USB Juicer Cup, Portable Juice Blender and Mix...
# B071YHPCDP  Hamilton Beach 67602A Big Mouth Juice Extracto...
# B071ZVQSP5  KUWAN Mini Rechargeable Electric Fruit Juicer ...
# B0722L18HQ  BuySevenSide Best Slow juicer Extractor High s...
# B0727PP8JX  USB Juicer Cup, Fruit Mixing Machine, Portable...
# B072F6YFXJ  TOWABO USB Juicer Cup, Fruit Mixing Machine, P...
# B072J2VHYJ  Mophorn Sugar Cane Press 50KG/H 0.2 inch Rolle...
# B072JSQ159  Portable Blender USB Juicer Cup Juicer Machine...
# B072SV42RJ  Frigidairenire Portable Electric Fruit Juicer ...
# B072WPDGDN  Portable Electronic USB Juicer Cup Fruit Mixin...
#
# [637 rows x 7 columns]

# %%
def clean_price(s):
    s = re.findall("\d+\.\d+",s)
    if s:
        return s[0]

# %%
df_all['price'] = df_all['price'][df_all['price'].notnull()].apply(clean_price)

# %%
df_all['price'] = df_all['price'].astype(float)

# %%
df_all.dropna(inplace=True)
df_all.shape
# Out:
# (622, 7)

# %%
df_all.pivot_table(index='category', values='price', aggfunc=np.mean)
# Out:
#                   price
# category
# centrifugal  186.435743
# citrus        99.309308
# masticating  302.206628

# %%
sns.stripplot(x='category', y='price', data=df_all)

# %%
plt.figure(figsize=(15,8))sns.boxplot(x='category', y='price', data=df_all)

# %%
plt.figure(figsize=(15,8))
sns.violinplot(x='category', y='price', data=df_all)

# %%
plt.figure(figsize=(15,8))
sns.violinplot(x='category', y='sales_rank', data=df_all)

# %%
plt.figure(figsize=(10,15))
sns.heatmap(df_all.pivot_table(index='brand', values=['price', 'sales_rank'], aggfunc=np.mean).apply(preprocessing.scale), cmap='magma')

# %%
sns.distplot(df_all[df_all['category']=='citrus']['price'].apply(np.log))

# %%
df_all.isnull().sum()
# Out:
# brand          0
# category       0
# color          0
# features       0
# price         15
# sales_rank     0
# title          0
# dtype: int64

# %%
#feature engineering on the category column
df_all['category'][df_all['category'] == 'citrus'] = 1
df_all['category'][df_all['category'] == 'centrifugal'] = 2
df_all['category'][df_all['category'] == 'masticating'] = 3
df_all.head()
# Out:
#                      brand category            color  \
# B00004R93U        juiceman        2        Off-White
# B00004R93V        juiceman        2            White
# B00004S8FH          waring        2            White
# B00004S8FJ          waring        1  Stainless Steel
# B00004X139  hamilton beach        2            White
#
#                                                      features   price  \
# B00004R93U  [Peppy 1/4-horsepower motor quickly juices mos...  158.98
# B00004R93V  [Powerful 1/2-horsepower motor quickly juices ...   79.95
# B00004S8FH  [Converts all noncitrus fruits and vegetables ...  360.00
# B00004S8FJ  [Juices all citrus fruits, from limes to grape...  149.99
# B00004X139  [This Hamilton Beach HealthSmart Juice Extract...   42.38
#
#            sales_rank                                              title
# B00004R93U    1006304       Juiceman Jr. Elite Pro JM211 Juice Extractor
# B00004R93V     778846  The Juiceman Electronic Professional Series 41...
# B00004S8FH     227195  Waring PJE401 Juice Extractor, Quite White and...
# B00004S8FJ     231125       Waring PCJ218 Citrus Juicer, Stainless Steel
# B00004X139     919971                        Juice Extractor,Healthsmart

# %%
df_all['sales_rank'] = df_all['sales_rank'].astype(int)

# %%
sns.distplot(df_all['sales_rank'])

# %%
sns.regplot(x='price', y='sales_rank', data=df_all)

# %%
sns.regplot(x='price', y='sales_rank', data=df_all[(df_all['category']=='citrus') & (df_all['price']<50)])

# %%
sns.regplot(x='price', y='sales_rank', data=df_all[df_all['category']=='masticating'])

# %%
sns.regplot(x='price', y='sales_rank', data=df_all[df_all['category']=='centrifugal'])

# %%
pd.options.mode.chained_assignment = None
#df_all['sales_rank'] /= 100

# %%
df_all['cat_rank'] = pd.cut(df_all['sales_rank'], 5)
rank_vs_price = df_all.pivot_table(index='cat_rank', values='price', aggfunc=np.mean)

# %%
rank_vs_price
# Out:
#                              price
# cat_rank
# (-4685.124, 1001143.8]  194.928350
# (1001143.8, 2001968.6]  278.634828
# (2001968.6, 3002793.4]  259.666923
# (3002793.4, 4003618.2]  879.000000
# (4003618.2, 5004443.0]   40.000000

# %%
def rank_feature(rank):
    if rank < 1001143.8:
        return 0
    if rank >= 1001143.8 and rank < 2001968.6:
        return 1
    if rank >= 2001968.6 and rank < 3002793.4:
        return 2
    if rank >= 3002793.4 and rank < 4003618.2:
        return 3
    if rank >= 4003618.2 and rank < 5004443.0:
        return 4

df_all['new_rank'] = df_all['sales_rank'].apply(rank_feature)
df_all.drop(['sales_rank', 'cat_rank'], axis=1, inplace=True)
df_all.head()
# Out:
#                      brand category            color  \
# B00004R93U        juiceman        2        Off-White
# B00004R93V        juiceman        2            White
# B00004S8FH          waring        2            White
# B00004S8FJ          waring        1  Stainless Steel
# B00004X139  hamilton beach        2            White
#
#                                                      features   price  \
# B00004R93U  [Peppy 1/4-horsepower motor quickly juices mos...  158.98
# B00004R93V  [Powerful 1/2-horsepower motor quickly juices ...   79.95
# B00004S8FH  [Converts all noncitrus fruits and vegetables ...  360.00
# B00004S8FJ  [Juices all citrus fruits, from limes to grape...  149.99
# B00004X139  [This Hamilton Beach HealthSmart Juice Extract...   42.38
#
#                                                         title  new_rank
# B00004R93U       Juiceman Jr. Elite Pro JM211 Juice Extractor       1.0
# B00004R93V  The Juiceman Electronic Professional Series 41...       0.0
# B00004S8FH  Waring PJE401 Juice Extractor, Quite White and...       0.0
# B00004S8FJ       Waring PCJ218 Citrus Juicer, Stainless Steel       0.0
# B00004X139                        Juice Extractor,Healthsmart       0.0

# %%
df_all.pivot_table(index='brand', values='price', aggfunc=np.mean).sort_values(by='price', ascending=False)
df_all = df_all[~df_all['price'].isnull()]
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 622 entries, B00004R93U to B072WPDGDN
# Data columns (total 7 columns):
# brand       622 non-null object
# category    622 non-null object
# color       622 non-null object
# features    622 non-null object
# price       622 non-null float64
# title       622 non-null object
# new_rank    621 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 38.9+ KB

# %%
brandlist = df_all['brand'].unique()
d = {}
for i, brand in enumerate(brandlist):
    d.update({brand:i})
    
df_all['brand'] = df_all['brand'].map(d)

# %%
df_all['color'] = df_all['color'].str.lower()

# %%
df_all['color'] = df_all['color'].replace(['stainless', 'steel', 'brushed stainless steel'], 'stainless steel')

# %%
colorlist = df_all['color'].unique()
d = {}
for i, color in enumerate(colorlist):
    d.update({color:i})
    
df_all['color'] = df_all['color'].map(d)

# %%
def featuring(lis):
    for l in lis:
        if "nut" in l:
            return 1
    else:
        return 0

df_all['features weight'] = df_all['features'].apply(featuring)

# %%
df_all.dropna(inplace=True)

# %%
df_train = df_all[['brand', 'category', 'color', 'new_rank', 'features weight']]
df_train
#X = np.array(df_all[['brand', 'category', 'color', 'new_rank', 'features weight']])
# Out:
#             brand category  color  new_rank  features weight
# B00004R93U      0        2      0       1.0                1
# B00004R93V      0        2      1       0.0                1
# B00004S8FH      1        2      1       0.0                0
# B00004S8FJ      1        1      2       0.0                0
# B00004X139      2        2      1       0.0                0
# B00005MF9O      3        1      3       1.0                0
# B00006IUZK      4        1      1       0.0                0
# B00009ENKU      5        3      1       0.0                0
# B00009KO85      1        2      2       0.0                0
# B0000DDVN4      6        2      4       0.0                0
# B0000DDVUO      1        2      5       0.0                0
# B0000VLI5K      7        1      2       0.0                0
# B0000ZP3MA      8        3      1       0.0                1
# B0000ZP3MK      8        3      1       0.0                1
# B00015NMWC      2        2      3       0.0                0
# B00016AFOE      9        2      1       1.0                0
# B0001IT0IY     10        2      6       0.0                0
# B0001LB9R6      3        2      1       0.0                1
# B00023XDJA     11        1      1       0.0                0
# B0002CA3TY      2        2      7       0.0                0
# B0002CA3U8      2        2      1       0.0                0
# B0002JNMEU      9        1      1       0.0                0
# B0002OKDT2      5        3      6       0.0                0
# B0006DOVGU     12        1      1       0.0                0
# B0007MU2O0      0        2      4       1.0                0
# B0007W160E     12        1      1       0.0                0
# B000AV3WF4     13        1      1       0.0                0
# B000E46IX0     14        3      8       0.0                1
# B000E48LGC     15        3      9       0.0                1
# B000E48LOY     16        3     10       0.0                0
# ...           ...      ...    ...       ...              ...
# B06XTDH92X    228        2     12       1.0                0
# B06XTQD8BX    229        3     33       0.0                0
# B06XVG9DTP     12        2     10       1.0                0
# B06XWT9KZ1    230        3     26       1.0                0
# B06XWWR9VM    231        2      1       0.0                0
# B06XXY3YYR    232        3     26       0.0                0
# B06XXYJYWM    202        1    119       0.0                0
# B06Y2DBF1T    233        2     25       0.0                0
# B06Y2K3Y6D     10        2      4       0.0                0
# B06ZXXP7DP    234        3     25       1.0                1
# B0711BC8YH    235        3     26       0.0                0
# B07174K6XQ    236        1     12       0.0                1
# B0718WJ3NR    237        2     10       0.0                0
# B0719Q7751    238        3     33       0.0                0
# B071D3WCTJ    132        2    120       0.0                1
# B071D549S7    195        2    121       0.0                0
# B071JL91JP    239        2    122       0.0                1
# B071JQXC8Y    240        2     25       0.0                0
# B071QYVR17      8        3     12       0.0                1
# B071RWG1YG    241        2     12       0.0                1
# B071VK2TBD    242        3      3       0.0                0
# B071YHPCDP      2        2      1       0.0                0
# B071ZVQSP5    243        2    123       0.0                0
# B0722L18HQ    235        3     26       0.0                1
# B0727PP8JX    244        2     25       0.0                0
# B072F6YFXJ    245        2      3       0.0                0
# B072J2VHYJ    219        2    124       0.0                0
# B072JSQ159    246        2     25       0.0                0
# B072SV42RJ    247        2     33       0.0                1
# B072WPDGDN    248        2      3       0.0                0
#
# [621 rows x 5 columns]

# %%
y = np.array(df_all['price'])

# %%
lr = linear_model.LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.33)
model = lr.fit(X_train, y_train)
print ("R^2 is: \n", model.score(X_test, y_test))
# Out:
# R^2 is:
#  0.203840122703
